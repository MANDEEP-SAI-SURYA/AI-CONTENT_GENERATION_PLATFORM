# %%
from utils.chatbot import ChatBot

# %%
chatbot = ChatBot()
chatbot.chat("Hi, I am Manideep")
# Out:
# "### Introduction\nHello Manideep, I'm here to help you with the latest news and information. \n> How can I assist you today? Are you looking for news on a specific topic or general current events?"

# %%
chatbot.chat("Can you tell me a trending cricket T20 news")
# Out:
# "### **Trending Cricket T20 News**\nFor the latest **cricket T20 news**, you can check out the following sources:\n- [Cricbuzz](https://www.cricbuzz.com/cricket-match/live-scores/recent-matches) for recent cricket results and scorecards, including IPL 2026 updates\n- [Hindustan Times](https://www.hindustantimes.com/cricket/live-score) for live scores and commentary on today's cricket matches\n- [LiveScore](https://www.livescore.com/en/cricket) for the latest cricket live scores, results, and fixtures\n\n> You can visit these websites for the most up-to-date information on cricket T20 news and matches.\n\n### **Key Stories**\n- Recent match results and scorecards are available on Cricbuzz\n- Live scores and commentary can be found on Hindustan Times\n- Fixtures and results for various cricket competitions are available on LiveScore\n\n### **Sources**\n- [Cricbuzz](https://www.cricbuzz.com)\n- [Hindustan Times](https://www.hindustantimes.com)\n- [LiveScore](https://www.livescore.com)"

# %%
chatbot.chat("Tell my name")
# Out:
# '### Your Name\nYour name is **Manideep**.'

# %%
from utils.web_scrapper import WebScrapper
scrapper = WebScrapper()
output = scrapper.search_agent()

# %%
output
# Out:
# [{'title': 'Health & Medicine News -- ScienceDaily',
# ...

# %%
from utils.Graph import graph
compiled_graph = graph.compile()
initial_state = {
    "results": [],
    "posts": []
}

compiled_graph.invoke(initial_state)
# Out:
#             Title: Trending: Latest Buzz in Pop Culture and News, Photos & Videos
#             Summary: BREAKING NEWS · James Van Der Beek Dies at 48. The wife of the ”Dawson's Creek” star, who was diagnosed in 2023 with colorectal cancer, shared that he
#             URL: https://www.today.com/trending
#
#
#             Title: Trending - The New York Times
# ...

# %%
from utils.arena_pulse import ArenaPulse
results = [{'url': 'https://www.nytimes.com/trending/',
  'title': 'Trending - The New York Times',
  'content': '# U.S. Attorney Chosen to Replace Trump Pick Is Quickly Fired by White House. # House Votes to Cancel Trump’s Canada Tariffs. # James Van Der Beek, Teenage Heartthrob of ‘Dawson’s Creek,’ Dies at 48. # What Trump Is the Best at, Hands Down. The most popular videos playing on Times Video right now. ## Will Trump’s Order on Housing Help? * ## Trump Allies Near ‘Total Victory’ in Wiping Out U.S. Climate Regulation. * ## Fake Post About Racist Video Looked to Be Trump’s on Truth Social. * ## Reaction to Trump’s Racist Post Shows He Is Not Always Immune to Politics. * ## ‘I Didn’t Make a Mistake’: Trump Declines to Apologize for Racist Video of Obamas. * ## James Van Der Beek, Teenage Heartthrob of ‘Dawson’s Creek,’ Dies at 48. * ## Former Police Chief Said Trump Told Him ‘Everyone’ Knew of Epstein’s Actions. * ## Trump Allies Near ‘Total Victory’ in Wiping Out U.S. Climate Regulation.',
  'score': 0.9891816,
  'raw_content': None}]

arena = ArenaPulse()
response = arena.create_post(results=results)
# Out:
#             Title: Trending - The New York Times
#             Summary: # U.S. Attorney Chosen to Replace Trump Pick Is Quickly Fired by White House. # House Votes to Cancel Trump’s Canada Tariffs. # James Van Der Beek, Teenage Heartthrob of ‘Dawson’s Creek,’ Dies at 48. # What Trump Is the Best at, Hands Down. The most popular videos playing on Times Video right now. ## Will Trump’s Order on Housing Help? * ## Trump Allies Near ‘Total Victory’ in Wiping Out U.S. Climate Regulation. * ## Fake Post About Racist Video Looked to Be Trump’s on Truth Social. * ## Reaction to Trump’s Racist Post Shows He Is Not Always Immune to Politics. * ## ‘I Didn’t Make a Mistake’: Trump Declines to Apologize for Racist Video of Obamas. * ## James Van Der Beek, Teenage Heartthrob of ‘Dawson’s Creek,’ Dies at 48. * ## Former Police Chief Said Trump Told Him ‘Everyone’ Knew of Epstein’s Actions. * ## Trump Allies Near ‘Total Victory’ in Wiping Out U.S. Climate Regulation.
# ...

# %%
response
# Out:
# {'title': 'Error',
#  'content': 'The provided summary contains multiple news articles and does not provide a clear, single topic to report on. The summary includes a variety of topics such as politics, entertainment, and more, making it difficult to generate a concise news report.',
#  'image_prompt': 'Generate a picture of a newspaper with a headline that says error',
#  'source_url': 'https://www.nytimes.com/trending/',
#  'topic': 'others'}

# %%
from utils.Graph import graph

from IPython.display import Image, display

compiled_graph = graph.compile()

display(Image(compiled_graph.get_graph().draw_mermaid_png()))
